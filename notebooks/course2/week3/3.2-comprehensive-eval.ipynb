# %% [markdown]
# # Lab 3.2: Comprehensive Evaluation
#
# **Objective**: Evaluate models with multiple metrics
#
# **Duration**: 25 minutes
#
# ## Learning Outcomes
# - Compute accuracy, F1, precision, recall
# - Generate confusion matrix
# - Interpret evaluation results

# %%
import sys
sys.path.insert(0, "../../../src")
from hf_ecosystem import __version__
print(f"hf-ecosystem version: {__version__}")

# %%
import numpy as np
import evaluate

# %% [markdown]
# ## 1. Multiple Metrics

# %%
# Sample data
predictions = [0, 1, 1, 0, 1, 0, 1, 0]
references = [0, 1, 0, 0, 1, 1, 1, 0]

# Load metrics
accuracy = evaluate.load("accuracy")
precision = evaluate.load("precision")
recall = evaluate.load("recall")
f1 = evaluate.load("f1")

results = {
    "accuracy": accuracy.compute(predictions=predictions, references=references)["accuracy"],
    "precision": precision.compute(predictions=predictions, references=references)["precision"],
    "recall": recall.compute(predictions=predictions, references=references)["recall"],
    "f1": f1.compute(predictions=predictions, references=references)["f1"],
}

for name, value in results.items():
    print(f"{name}: {value:.3f}")

# %% [markdown]
# ## 2. Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(references, predictions)
print(f"Confusion Matrix:\n{cm}")

# %% [markdown]
# ## Verification

# %%
def verify_lab():
    assert "accuracy" in results
    assert cm.shape == (2, 2)
    print("✅ Lab completed successfully!")

verify_lab()
